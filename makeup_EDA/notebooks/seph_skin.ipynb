# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### How can I recommend products for specific skin types based on this data?

# %%
df_1 = pd.read_csv('c:\sephora\cosmetic_p.csv', delimiter=',')
print(df_1)
# Out:
#             Label                          brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    name  price  rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
print(df_1.dtypes)
# Out:
# Label           object
# brand           object
# name            object
# price            int64
# rank           float64
# ingredients     object
# Combination      int64
# Dry              int64
# Normal           int64
# Oily             int64
# Sensitive        int64
# dtype: object

# %%
print(df_1.columns)
# Out:
# Index(['Label', 'brand', 'name', 'price', 'rank', 'ingredients', 'Combination',
#        'Dry', 'Normal', 'Oily', 'Sensitive'],
#       dtype='object')

# %%
df_1.head(30)
# Out:
#           Label               brand  \
# 0   Moisturizer              LA MER
# 1   Moisturizer               SK-II
# 2   Moisturizer      DRUNK ELEPHANT
# 3   Moisturizer              LA MER
# 4   Moisturizer        IT COSMETICS
# 5   Moisturizer              TATCHA
# 6   Moisturizer      DRUNK ELEPHANT
# 7   Moisturizer      DRUNK ELEPHANT
# 8   Moisturizer  KIEHL'S SINCE 1851
# 9   Moisturizer              LA MER
# 10  Moisturizer               FRESH
# 11  Moisturizer  KIEHL'S SINCE 1851
# 12  Moisturizer               BELIF
# 13  Moisturizer        SUNDAY RILEY
# 14  Moisturizer             FARMACY
# 15  Moisturizer      DRUNK ELEPHANT
# 16  Moisturizer    FIRST AID BEAUTY
# 17  Moisturizer            CLINIQUE
# 18  Moisturizer               FRESH
# 19  Moisturizer               SK-II
# 20  Moisturizer              LA MER
# 21  Moisturizer        BAREMINERALS
# 22  Moisturizer            SHISEIDO
# 23  Moisturizer               FRESH
# 24  Moisturizer               BELIF
# ...

# %%
sorted_df = df_1.sort_values(by='price', ascending=False)
sorted_df.head(30)
# Out:
#             Label         brand  \
# 587     Treatment        LA MER
# 601     Treatment        LA MER
# 9     Moisturizer        LA MER
# 790     Treatment      SHISEIDO
# 665     Treatment     BIOEFFECT
# 85    Moisturizer         FRESH
# 170   Moisturizer      SHISEIDO
# 669     Treatment        LANCER
# 708     Treatment        LANCER
# 162   Moisturizer        LA MER
# 293   Moisturizer        LA MER
# 818     Treatment         FRESH
# 1181    Eye cream  AMOREPACIFIC
# 1454  Sun protect      SHISEIDO
# 1340  Sun protect      SHISEIDO
# 1120    Eye cream        LA MER
# 1068    Face Mask        LANCER
# 871     Face Mask        LA MER
# 840     Face Mask        LA MER
# 636     Treatment        LA MER
# 52    Moisturizer        LA MER
# 811     Treatment         FRESH
# 29    Moisturizer         SK-II
# 19    Moisturizer         SK-II
# 1271    Eye cream      GUERLAIN
# 116   Moisturizer         SK-II
# 147   Moisturizer         SK-II
# 1101    Eye cream        LA MER
# ...

# %%
sorted_df1 = df_1.sort_values(by='rank', ascending=False)
sorted_df1.head(40)
# Out:
#             Label                      brand  \
# 618     Treatment                  BIOEFFECT
# 966     Face Mask         SEPHORA COLLECTION
# 1219    Eye cream               PERRICONE MD
# 1003    Face Mask                      FOREO
# 228   Moisturizer                       DIOR
# 177   Moisturizer                NURSE JAMIE
# 755     Treatment  DR. DENNIS GROSS SKINCARE
# 999     Face Mask               AMOREPACIFIC
# 830     Face Mask         SEPHORA COLLECTION
# 1458  Sun protect                      COOLA
# 1340  Sun protect                   SHISEIDO
# 990     Face Mask                 OMOROVICZA
# 988     Face Mask                   GLAMGLOW
# 974     Face Mask         SEPHORA COLLECTION
# 848     Face Mask         SEPHORA COLLECTION
# 1167    Eye cream                      FRESH
# 1409  Sun protect                 SUPERGOOP!
# 244   Moisturizer                    LANEIGE
# 1254    Eye cream                  BEAUTYBIO
# 724     Treatment                       DIOR
# ...

# %%
df_2 = df_1[df_1['Label']=='Moisturizer']
df_2.head(30)
# Out:
#           Label               brand  \
# 0   Moisturizer              LA MER
# 1   Moisturizer               SK-II
# 2   Moisturizer      DRUNK ELEPHANT
# 3   Moisturizer              LA MER
# 4   Moisturizer        IT COSMETICS
# 5   Moisturizer              TATCHA
# 6   Moisturizer      DRUNK ELEPHANT
# 7   Moisturizer      DRUNK ELEPHANT
# 8   Moisturizer  KIEHL'S SINCE 1851
# 9   Moisturizer              LA MER
# 10  Moisturizer               FRESH
# 11  Moisturizer  KIEHL'S SINCE 1851
# 12  Moisturizer               BELIF
# 13  Moisturizer        SUNDAY RILEY
# 14  Moisturizer             FARMACY
# 15  Moisturizer      DRUNK ELEPHANT
# 16  Moisturizer    FIRST AID BEAUTY
# 17  Moisturizer            CLINIQUE
# 18  Moisturizer               FRESH
# 19  Moisturizer               SK-II
# 20  Moisturizer              LA MER
# 21  Moisturizer        BAREMINERALS
# 22  Moisturizer            SHISEIDO
# 23  Moisturizer               FRESH
# 24  Moisturizer               BELIF
# ...

# %%
sorted_df2 = df_2.sort_values(by='rank', ascending=False)
sorted_df2.head(50)
# Out:
#            Label                brand  \
# 244  Moisturizer              LANEIGE
# 228  Moisturizer                 DIOR
# 194  Moisturizer             CLINIQUE
# 177  Moisturizer          NURSE JAMIE
# 9    Moisturizer               LA MER
# 149  Moisturizer   REN CLEAN SKINCARE
# 231  Moisturizer         ESTÉE LAUDER
# 51   Moisturizer  YOUTH TO THE PEOPLE
# 196  Moisturizer             SHISEIDO
# 131  Moisturizer  YOUTH TO THE PEOPLE
# 129  Moisturizer                FRESH
# 297  Moisturizer                GO-TO
# 113  Moisturizer                BELIF
# 184  Moisturizer         ESTÉE LAUDER
# 130  Moisturizer                BELIF
# 125  Moisturizer   KIEHL'S SINCE 1851
# 232  Moisturizer             CLINIQUE
# 119  Moisturizer            BIOSSANCE
# 284  Moisturizer             CLINIQUE
# 289  Moisturizer   KIEHL'S SINCE 1851
# 161  Moisturizer              ORIGINS
# 266  Moisturizer             SHISEIDO
# 94   Moisturizer              LANEIGE
# ...

# %%
df_2.corr()
# Out:
#                 price      rank  Combination       Dry    Normal      Oily  \
# price        1.000000 -0.168764    -0.065606  0.027980  0.001451 -0.026138
# rank        -0.168764  1.000000     0.036722  0.046243  0.114023  0.059194
# Combination -0.065606  0.036722     1.000000  0.698387  0.809087  0.806868
# Dry          0.027980  0.046243     0.698387  1.000000  0.780173  0.568330
# Normal       0.001451  0.114023     0.809087  0.780173  1.000000  0.714576
# Oily        -0.026138  0.059194     0.806868  0.568330  0.714576  1.000000
# Sensitive    0.023610  0.085449     0.641070  0.654672  0.668371  0.573501
#
#              Sensitive
# price         0.023610
# rank          0.085449
# Combination   0.641070
# Dry           0.654672
# Normal        0.668371
# Oily          0.573501
# Sensitive     1.000000

# %%
sorted_df3 = df_2.sort_values(by='price', ascending=False)
sorted_df3.head(50)
# Out:
#            Label              brand  \
# 9    Moisturizer             LA MER
# 85   Moisturizer              FRESH
# 170  Moisturizer           SHISEIDO
# 162  Moisturizer             LA MER
# 293  Moisturizer             LA MER
# 52   Moisturizer             LA MER
# 29   Moisturizer              SK-II
# 19   Moisturizer              SK-II
# 116  Moisturizer              SK-II
# 147  Moisturizer              SK-II
# 78   Moisturizer       AMOREPACIFIC
# 97   Moisturizer             LA MER
# 288  Moisturizer            LANCÔME
# 1    Moisturizer              SK-II
# 98   Moisturizer             LA MER
# 258  Moisturizer               DIOR
# 166  Moisturizer            LANCÔME
# 0    Moisturizer             LA MER
# 3    Moisturizer             LA MER
# 204  Moisturizer               DIOR
# 208  Moisturizer              SK-II
# 281  Moisturizer              SK-II
# 212  Moisturizer       AMOREPACIFIC
# 213  Moisturizer              FRESH
# 82   Moisturizer       AMOREPACIFIC
# ...

# %%
#moisturizer price compare rank

plt.scatter(df_2['price'], df_2['rank'])

# Set labels and title

plt.xlabel("Product Price")
plt.ylabel("Customer Ratings")
plt.title("Product Price vs. Customer Ratings")

# Display the plot
plt.show()
